# %%
# Cleans up all the data and generated the distribution of course reviews (distribution.png)
import os 
import json
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.getcwd()
# Out:
# '/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/scrape-q-guide-master/data'

# %%
os.chdir(os.getcwd() + "/data")

# %%
files = os.listdir(os.getcwd())[3:-1]

# %%
len(files)
# Out:
# 4583

# %%
files
# Out:
# ['AESTH&INTP 11.json',
#  'AESTH&INTP 12.json',
#  'AESTH&INTP 14.json',
#  'AESTH&INTP 15.json',
#  'AESTH&INTP 16.json',
#  'AESTH&INTP 20.json',
#  'AESTH&INTP 21.json',
#  'AESTH&INTP 23.json',
#  'AESTH&INTP 25.json',
#  'AESTH&INTP 26.json',
#  'AESTH&INTP 29.json',
#  'AESTH&INTP 30.json',
#  'AESTH&INTP 31.json',
#  'AESTH&INTP 34.json',
#  'AESTH&INTP 35.json',
#  'AESTH&INTP 36.json',
#  'AESTH&INTP 38.json',
#  'AESTH&INTP 40.json',
#  'AESTH&INTP 41.json',
#  'AESTH&INTP 42.json',
#  'AESTH&INTP 43.json',
#  'AESTH&INTP 44.json',
#  'AESTH&INTP 47.json',
#  'AESTH&INTP 51.json',
#  'AESTH&INTP 54.json',
#  'AESTH&INTP 56.json',
#  'AESTH&INTP 58.json',
#  'AESTH&INTP 59.json',
#  'AESTHINT 13.json',
#  'AESTHINT 24.json',
#  'AESTHINT 33.json',
#  'AESTHINT 37.json',
#  'AESTHINT 39.json',
#  'AESTHINT 54.json',
#  'AESTHINT 55.json',
#  'AESTHINT 57.json',
#  'AESTHINT 60.json',
#  'AESTHINT 62.json',
#  'AESTHINT 63.json',
#  'AESTHINT 64.json',
#  'AFRAMER 10.json',
# ...

# %%
# for file in files:
#     with open(file) as f:
#         data = json.load(f)
#     try:
#         term = data['scores'].keys()[0]
#     except AttributeError:
#         continue
#     try:
#         course_name = str(data['scores'][term]['instructor_scores'][0]['number'])
#     except KeyError:
#         continue
#     os.rename(file, course_name+".json")

# %%
files[0].split(" ")[0]
# Out:
# 'AESTH&INTP'

# %%
file = 'Stat 110.json'

# %%
data = json.load(open(file))

# %%
data['comments']
# Out:
# {u"Fall '07": {u'comments': [u"This class is difficult but well taught.  If you like math, I'd recommend taking it instead of an easier course.",
#    u'Tough but very interesting.',
#    u'Wonderfully taught. Very rewarding. Terribly difficult if you are not a strong math student.',
#    u"It's a difficult class. Be prepared to work hard if you want to understand anything and do well.",
#    u"Well taught but very challenging.  Probably the hardest class I've taken at Harvard.",
#    u'Very interesting but very hard',
#    u'This course is not too difficult and the material is pretty interesting. Take it!',
#    u'I have actually used things that I learned in this class in my day-to-day life, which is kind of pathetic, but really cool.',
# ...

# %%
courses = {}
for file in files:
    subj = file.split(" ")[0]
    if subj not in courses:
        courses[subj] = 1
    else:
        courses[subj] += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a53c5d6eaaf> in <module>()
#       1 courses = {}
# ----> 2 for file in files:
#       3     subj = file.split(" ")[0]
#       4     if subj not in courses:
#       5         courses[subj] = 1
#
# NameError: name 'files' is not defined

# %%
most_pop = sorted(courses, key=courses.get)[::-1][0:20]

# %%
most_courses = {}
for pop in most_pop:
    most_courses[pop] = courses[pop]

# %%
most_courses
# Out:
# {'AFRAMER': 95,
#  'ANTHRO': 159,
#  'COMPSCI': 67,
#  'ECON': 155,
#  'ENG-SCI': 95,
#  'ENGLISH': 171,
#  'EXPOS': 204,
#  'FRSEMR': 255,
#  'GOV': 188,
#  'HAA': 134,
#  'HIST': 278,
#  'HISTSCI': 112,
#  'MATH': 85,
#  'MUSIC': 100,
#  'OEB': 77,
#  'PHIL': 76,
#  'PSY': 157,
#  'RELIGION': 68,
#  'SOCIOL': 109,
#  'VES': 139}

# %%
help(plt.xticks)
# Out:
# Help on function xticks in module matplotlib.pyplot:
#
# xticks(*args, **kwargs)
#     Get or set the *x*-limits of the current tick locations and labels.
#
#     ::
#
#       # return locs, labels where locs is an array of tick locations and
#       # labels is an array of tick labels.
#       locs, labels = xticks()
#
#       # set the locations of the xticks
#       xticks( arange(6) )
#
#       # set the locations and labels of the xticks
#       xticks( arange(5), ('Tom', 'Dick', 'Harry', 'Sally', 'Sue') )
#
#     The keyword args, if any, are :class:`~matplotlib.text.Text`
#     properties. For example, to rotate long labels::
#
#       xticks( arange(12), calendar.month_name[1:13], rotation=17 )

# %%
plt.bar(range(len(most_courses.keys())), most_courses.values(), width = 1)
plt.xticks(range(len(most_courses.keys())), most_courses.keys(), rotation=90)
plt.show()

# %%
for file in files:
    with open(file) as f:
        try:
            data = json.load(f)
        except ValueError:
            os.remove(file)
            continue
    if data['comments'] == []:
        os.remove(file)
    else:
        count += 1
        print file
print float(count)/total

# %%
os.chdir(os.getcwd() + "/data")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-91-db7523dea886> in <module>()
# ----> 1 os.chdir(os.getcwd() + "/data")
#
# OSError: [Errno 2] No such file or directory: '/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/scrape-q-guide-master/data/data'

# %%
data['comments'].values()[0].values()[0]
# Out:
# [u'Make sure you are very comfortable with high school and 21a level calculus. Make sure you understand functions (they are more nuanced than people realize) and infinite series (which people tend to forget after the AP). Know that there are very good materials available online to supplement Professor Blitzstein\'s book. State colleges have a lot of material freely available. To really learn a topic, find some straight-forward practice problems online (just Google "[topic name] solved problems"), drill those problems, then do the problems from the book then the homework problems. Make sure you take the time to learn the math notation and keywords used in the book. This can be done with a small amount of Googling as well. Symmetry is a bit of an elusive topic, but make sure you get a grip on that right away. Note that symmetry appears when dealing with distributions (e.g. the Normal) as well as random variables (e.g. iid random variables). Be sure that you can do every example in the 
# ...

# %%
comment.encode('ascii', 'ignore').replace('\r\n', '')
# Out:
# "Prof. New is great, and is tolerant of and pays close attention to your commentsbut also won't accept a lot of crap. The papers are difficult, and must be quite original and well-constructed. You'll learn a lot about American history and how poetry functions in addition to the particular history of American poetry."

# %%
os.chdir("/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/scrape-q-guide-master"+ "/data")
current_subject = ""
for file in files:
    with open(file) as f:
        data = json.load(f)
    subject = file.split('.json')[0].split(' ')[0]
    os.chdir("/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/scrape-q-guide-master/cleaned_data")
    subjects = os.listdir(os.getcwd())
    if subject != current_subject:
        print "ON NEW SUBJECT: " + str(subject)
        current_subject = subject
    if not os.path.exists(subject):
        os.makedirs(subject)
    os.chdir(os.getcwd()+ "/" + subject)
    f = open(file.split('.json')[0] + ".txt", 'wb')
    comments = data['comments'].values()
    for i in range(len(comments)):
        comment_list = comments[i].values()[0]
        for comment in comment_list:
            comment = comment.encode('ascii', 'ignore').replace('\r\n', '')
            f.write(comment +"\n")
    f.close()
    os.chdir("/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/scrape-q-guide-master"+ "/data")
# Out:
# ON NEW SUBJECT: AESTH&INTP
# ON NEW SUBJECT: AESTHINT
# ON NEW SUBJECT: AFRAMER
# ON NEW SUBJECT: AKKAD
# ON NEW SUBJECT: AM-CIV
# ON NEW SUBJECT: AMSTDIES
# ON NEW SUBJECT: ANE
# ON NEW SUBJECT: ANTHRO
# ON NEW SUBJECT: APCOMP
# ON NEW SUBJECT: APMTH
# ON NEW SUBJECT: APPHY
# ON NEW SUBJECT: ARABIC
# ON NEW SUBJECT: ARAMAIC
# ON NEW SUBJECT: ARMEN
# ON NEW SUBJECT: ARMENST
# ON NEW SUBJECT: ASTRON
# ON NEW SUBJECT: BBS
# ON NEW SUBJECT: BCMP
# ON NEW SUBJECT: BCS
# ON NEW SUBJECT: BE
# ON NEW SUBJECT: BIOPHYS
# ON NEW SUBJECT: BIOSTAT
# ON NEW SUBJECT: BPH
# ON NEW SUBJECT: CATALAN
# ON NEW SUBJECT: CELLBIO
# ON NEW SUBJECT: CELTIC
# ON NEW SUBJECT: CHEM
# ON NEW SUBJECT: CHEMBIO
# ON NEW SUBJECT: CHNSE
# ON NEW SUBJECT: CHNSHIS
# ON NEW SUBJECT: CHNSLIT
# ON NEW SUBJECT: CLAS-HEB
# ON NEW SUBJECT: CLAS-STDY
# ON NEW SUBJECT: CLASARCH
# ON NEW SUBJECT: CLASPHIL
# ON NEW SUBJECT: CLASSIC
# ON NEW SUBJECT: COMPLIT
# ON NEW SUBJECT: COMPSCI
# ON NEW SUBJECT: CPB
# ...

# %%
os.getcwd()
# Out:
# '/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/scrape-q-guide-master/data'

# %%
os.chdir("/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/scrape-q-guide-master/cleaned_data/AESTH&INTP")

# %%
f = open(os.listdir(os.getcwd())[1], 'rb')

# %%
f = f.read()

# %%
a = "sdfksdf\n"

# %%
a.replace('\n', '')
# Out:
# 'sdfksdf'

# %%
f.split('\n')
# Out:
# ['If you sincerely care about contemporary international poetry, you will not regret this class. You have so much flexibility to explore the parts of poetry that matter to you AND learn about poets you would have otherwise never heard of. Although this is a Gen Ed, it will not be fun unless you truly enjoy poetry. The workload in this class is what you make out of it. The required readings are not that many, but there is a lot of supplementary poetry. At the end of the semester, you compile a portfolio with your own work and analysis, which is BY FAR one of the best assignments I have had during my time at Harvard.',
# ...

# %%
os.chdir('/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/cleaned_data')

# %%
os.chdir("cleaned_data")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-936511da4d5c> in <module>()
# ----> 1 os.chdir("cleaned_data")
#
# OSError: [Errno 2] No such file or directory: 'cleaned_data'

# %%
directories = os.listdir(os.getcwd())

# %%
directories
# Out:
# ['AESTH&INTP',
#  'AESTHINT',
#  'AFRAMER',
#  'AKKAD',
#  'AM-CIV',
#  'AMSTDIES',
#  'ANE',
#  'ANTHRO',
#  'APCOMP',
#  'APMTH',
#  'APPHY',
#  'ARABIC',
#  'ARAMAIC',
#  'ARMEN',
#  'ARMENST',
#  'ASTRON',
#  'BBS',
#  'BCMP',
#  'BCS',
#  'BE',
#  'BIOPHYS',
#  'BIOSTAT',
#  'BPH',
#  'CATALAN',
#  'CELLBIO',
#  'CELTIC',
#  'CHEM',
#  'CHEMBIO',
#  'CHNSE',
#  'CHNSHIS',
#  'CHNSLIT',
#  'CLAS-HEB',
#  'CLAS-STDY',
#  'CLASARCH',
#  'CLASPHIL',
#  'CLASSIC',
#  'COMPLIT',
#  'COMPSCI',
#  'CPB',
#  'CULTBLF',
#  'CULTR&BLF',
#  'CZCH',
#  'DRAMA',
#  'DRB',
#  'E&M-REASON',
#  'E-PSCI',
#  'EABS',
#  'EAFM',
#  'EASTD',
#  'ECON',
#  'EGYPTIAN',
#  'EMR',
#  'EMREAS',
#  'ENG-SCI',
#  'ENGLISH',
#  'ESPP',
#  'ETH-REASON',
#  'ETHRSON',
#  'EXPOS',
#  'FOLKMYTH',
#  'FRENCH',
#  'FRSEMR',
#  'GENETIC',
#  'GERM-STD',
#  'GERMAN',
#  'GHHP',
#  'GIKUYU',
#  'GOV',
#  'GREEK',
#  'HAA',
#  'HBTM',
#  'HEB',
#  'HEBREW',
#  'HIND-URD',
#  'HIST',
#  'HIST-LIT',
#  'HISTSCI',
# ...

# %%
counts = {}
for direc in directories:
    os.chdir(direc)
    counts[direc] = len(os.listdir(os.getcwd()))
    os.chdir('/Users/TimothyKang/Dropbox/Harvard/Senior Spring 2018/AM 231/HW/Project/cleaned_data')

# %%
counts
# Out:
# {'AESTH&INTP': 29,
#  'AESTHINT': 12,
#  'AFRAMER': 95,
#  'AKKAD': 4,
#  'AM-CIV': 1,
#  'AMSTDIES': 1,
#  'ANE': 10,
#  'ANTHRO': 159,
#  'APCOMP': 6,
#  'APMTH': 26,
#  'APPHY': 18,
#  'ARABIC': 27,
#  'ARAMAIC': 1,
#  'ARMEN': 1,
#  'ARMENST': 1,
#  'ASTRON': 31,
#  'BBS': 2,
#  'BCMP': 13,
#  'BCS': 2,
#  'BE': 8,
#  'BIOPHYS': 6,
#  'BIOSTAT': 18,
#  'BPH': 9,
#  'CATALAN': 2,
#  'CELLBIO': 9,
#  'CELTIC': 19,
#  'CHEM': 36,
#  'CHEMBIO': 2,
#  'CHNSE': 21,
#  'CHNSHIS': 12,
#  'CHNSLIT': 22,
#  'CLAS-HEB': 1,
#  'CLAS-STDY': 11,
#  'CLASARCH': 7,
#  'CLASPHIL': 13,
#  'CLASSIC': 3,
#  'COMPLIT': 36,
#  'COMPSCI': 67,
#  'CPB': 3,
#  'CULTBLF': 11,
#  'CULTR&BLF': 31,
#  'CZCH': 4,
#  'DRAMA': 17,
#  'DRB': 2,
#  'E&M-REASON': 8,
#  'E-PSCI': 50,
#  'EABS': 4,
#  'EAFM': 14,
#  'EASTD': 15,
#  'ECON': 155,
#  'EGYPTIAN': 1,
#  'EMR': 1,
#  'EMREAS': 2,
#  'ENG-SCI': 95,
#  'ENGLISH': 171,
#  'ESPP': 16,
#  'ETH-REASON': 18,
#  'ETHRSON': 6,
#  'EXPOS': 204,
#  'FOLKMYTH': 19,
# ...

# %%
most_pop = sorted(counts, key=counts.get)[::-1][0:25]

# %%
most_pop
# Out:
# ['HIST',
#  'FRSEMR',
#  'EXPOS',
#  'GOV',
#  'ENGLISH',
#  'ANTHRO',
#  'PSY',
#  'ECON',
#  'VES',
#  'HAA',
#  'HISTSCI',
#  'SOCIOL',
#  'MUSIC',
#  'ENG-SCI',
#  'AFRAMER',
#  'MATH',
#  'OEB',
#  'PHIL',
#  'RELIGION',
#  'COMPSCI',
#  'STAT',
#  'SLAVIC',
#  'MCB',
#  'SPANSH',
#  'WOMGEN']

# %%
most_pop
# Out:
# ['HIST',
#  'FRSEMR',
#  'EXPOS',
#  'GOV',
#  'ENGLISH',
#  'ANTHRO',
#  'PSY',
#  'ECON',
#  'VES',
#  'HAA',
#  'HISTSCI',
#  'SOCIOL',
#  'MUSIC',
#  'ENG-SCI',
#  'AFRAMER',
#  'MATH',
#  'OEB',
#  'PHIL',
#  'RELIGION',
#  'COMPSCI',
#  'STAT',
#  'SLAVIC',
#  'MCB',
#  'SPANSH',
#  'WOMGEN']

# %%
counts_new = []
for pop in most_pop:
    counts_new.append(counts[pop])

# %%
counts_new
# Out:
# [278,
#  255,
#  204,
#  188,
#  171,
#  159,
#  157,
#  155,
#  139,
#  134,
#  112,
#  109,
#  100,
#  95,
#  95,
#  85,
#  77,
#  76,
#  68,
#  67,
#  59,
#  58,
#  56,
#  56,
#  54]

# %%
plt.bar(range(len(most_pop)), counts_new)
plt.xticks(range(len(most_pop)), most_pop, rotation=90)
plt.savefig('distribution.png')
plt.show()
